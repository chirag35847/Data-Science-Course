# %% [markdown]
# ## Intro to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4])

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
plt.plot(2)

# %%
#Matplaotlib 4th video
# Recommended method for ploting
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250])

# %% [markdown]
# ## Maltplot example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x=[1,2,3,4]
y=[11,22,33,44]

# 2. Setup plot
fig,ax=plt.subplots(figsize=(5,5)) # (width,height)

# 3. Plot Data
ax.plot(x,y)

# 4. Customize plot
ax.set(title="Simple Plot",xlabel="x-axis",ylabel="y-axis")
# Out:
# [Text(0.5, 1.0, 'Simple Plot'), Text(0.5, 0, 'x-axis'), Text(0, 0.5, 'y-axis')]

# %% [markdown]
# ## Making fugures with Numpy arrays

# %%
import pandas as pd
import numpy as np

# %%
x=np.linspace(0,10,num=100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# plot the data
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.cos(x))

# %%
# Make a plot from dict
nut_butter_prices={"Almond Butter":10,"Peanut Butter":8,"Cashew Butter":12}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Nut Butter Prices Shop",xlabel="Types of butter",ylabel="Cost in $");

# %%
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

ax2.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));
ax3.scatter(x,np.exp(x))
ax4.scatter(x,np.cos(x))

# %%
# Option 2
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(20,10))
ax[0,0].hist(x);
ax[0,1].scatter(x,np.sin(x))
ax[1,0].scatter(x,np.sin(x))
ax[1,1].bar(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Plotting from Pandas Dataframe

# %%
car_sales=pd.read_csv("7.1 car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2021",periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] =car_sales['Price'].replace('[\$\,\.]', '', regex=True).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"]/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Sales Date"]=pd.date_range("18/11/2021",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Sales Date
# 0  Toyota  White         150043      4   4000.0 2021-11-18
# 1   Honda    Red          87899      4   5000.0 2021-11-19
# 2  Toyota   Blue          32549      3   7000.0 2021-11-20
# 3     BMW  Black          11179      5  22000.0 2021-11-21
# 4  Nissan  White         213095      4   3500.0 2021-11-22
# 5  Toyota  Green          99213      4   4500.0 2021-11-23
# 6   Honda   Blue          45698      4   7500.0 2021-11-24
# 7   Honda   Blue          54738      4   7000.0 2021-11-25
# 8  Toyota  White          60000      4   6250.0 2021-11-26
# 9  Nissan  White          31600      4   9700.0 2021-11-27

# %%
car_sales["Total Sales"]=car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2021-11-18       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-11-19       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-11-20      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-11-21      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-11-22      41500.0
# 5  Toyota  Green          99213      4   4500.0 2021-11-23      46000.0
# 6   Honda   Blue          45698      4   7500.0 2021-11-24      53500.0
# 7   Honda   Blue          54738      4   7000.0 2021-11-25      60500.0
# 8  Toyota  White          60000      4   6250.0 2021-11-26      66750.0
# 9  Nissan  White          31600      4   9700.0 2021-11-27      76450.0

# %%
car_sales.plot(x="Sales Date",y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
x=np.random.rand(10,4)
x
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.137891  0.733430  0.274397  0.826041
# 1  0.790578  0.567009  0.754777  0.339951
# 2  0.810321  0.842824  0.332674  0.508464
# 3  0.064225  0.702134  0.951367  0.967733
# 4  0.408000  0.436739  0.009691  0.607860
# 5  0.771923  0.100329  0.317035  0.344083
# 6  0.125224  0.096846  0.490419  0.267493
# 7  0.622709  0.918629  0.697065  0.981399
# 8  0.374218  0.965754  0.819056  0.993955
# 9  0.545537  0.548090  0.978311  0.330514

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2021-11-18       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-11-19       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-11-20      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-11-21      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-11-22      41500.0
# 5  Toyota  Green          99213      4   4500.0 2021-11-23      46000.0
# 6   Honda   Blue          45698      4   7500.0 2021-11-24      53500.0
# 7   Honda   Blue          54738      4   7000.0 2021-11-25      60500.0
# 8  Toyota  White          60000      4   6250.0 2021-11-26      66750.0
# 9  Nissan  White          31600      4   9700.0 2021-11-27      76450.0

# %%
heart_disease=pd.read_csv("13.1 heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease.plot.hist(figsize=(20,40),subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### Which one should we use
# * When plotting quickly, pyplot is fine
# * When plotting something advanced use OO Method

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind="scatter",x='age',y='chol',c='target')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fix,ax=plt.subplots(figsize=(10,6))
# ax.scatter(over_50["age"],over_50['chol'],c=over_50['target'])
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax)
ax.set_xlabel("AGE")
# Out:
# Text(0.5, 0, 'AGE')

# %%
fix,ax=plt.subplots(figsize=(10,6))
scatter=ax.scatter(x=over_50["age"],y=over_50['chol'],c=over_50['target'])
ax.set(title="Heart Disease and Cholesterol Levels",xlabel="AGE",ylabel="Cholesterol Level")

# Add legend
ax.legend(*scatter.legend_elements(),title="Target")

# Add horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--")

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
## 16th Video 15th in index
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'])
ax0.set(title='Choletrol VS Age for heart disease',ylabel="Cholestrol Level")
ax0.legend(*scatter.legend_elements(),title='target')
ax0.axhline(over_50['chol'].mean(),linestyle="--")

scatter=ax1.scatter(x=over_50['age'],y=over_50['thalach'],c=over_50['target'])
ax1.set(title='Max Heart Rate VS Age for heart disease',xlabel="Age in years",ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(),title='target')
ax1.axhline(over_50['thalach'].mean(),linestyle="--")

## add title to figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib plots

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2021-11-18       4000.0
# 1   Honda    Red          87899      4   5000.0 2021-11-19       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2021-11-20      16000.0
# 3     BMW  Black          11179      5  22000.0 2021-11-21      38000.0
# 4  Nissan  White         213095      4   3500.0 2021-11-22      41500.0

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn-dark')
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
# Create Dummy Data
x=np.random.randn(10,4)
x
# Out:
# array([[-0.47143666,  1.49496861,  1.20429091,  0.39430867],
#        [-1.36185623, -0.93218337,  0.63645238,  0.35631403],
#        [-1.04035944,  0.61902287,  1.03496214, -0.19162206],
#        [ 0.84651707, -0.80963372,  0.70217237, -1.10493162],
#        [-0.54514266, -1.24969566,  0.79498741,  0.92717754],
#        [ 1.12939973,  1.09047424,  0.21713836, -0.39070025],
#        [ 0.72750926,  1.93165394, -0.71766329, -2.69418842],
#        [ 0.06936998, -0.2131028 ,  1.23346268, -1.76405763],
#        [-1.63141212, -2.04957097, -1.55743764, -1.65015914],
#        [-0.1238685 , -1.4510089 ,  0.74765026, -0.40860763]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.471437  1.494969  1.204291  0.394309
# 1 -1.361856 -0.932183  0.636452  0.356314
# 2 -1.040359  0.619023  1.034962 -0.191622
# 3  0.846517 -0.809634  0.702172 -1.104932
# 4 -0.545143 -1.249696  0.794987  0.927178
# 5  1.129400  1.090474  0.217138 -0.390700
# 6  0.727509  1.931654 -0.717663 -2.694188
# 7  0.069370 -0.213103  1.233463 -1.764058
# 8 -1.631412 -2.049571 -1.557438 -1.650159
# 9 -0.123869 -1.451009  0.747650 -0.408608

# %%
ax = df.plot(kind='bar')

# %%
# Customize
ax=df.plot(kind='bar')
ax.set(title="Random Graph",xlabel="Row",ylabel="Col")

ax.legend().set_visible(True)

# %%
plt.style.use("seaborn-whitegrid")
fix,ax=plt.subplots(figsize=(10,6))
scatter=ax.scatter(x=over_50["age"],y=over_50['chol'],c=over_50['target'],cmap='winter')
ax.set(title="Heart Disease and Cholesterol Levels",xlabel="AGE",ylabel="Cholesterol Level")

# Add legend
ax.legend(*scatter.legend_elements(),title="Target")

# Add horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--")

# %%
# Customize the y and x axis limitations

fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter=ax0.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'],cmap='winter')
ax0.set(title='Choletrol VS Age for heart disease',ylabel="Cholestrol Level")
ax0.legend(*scatter.legend_elements(),title='target')
ax0.axhline(over_50['chol'].mean(),linestyle="--")
ax0.set_xlim([50,80])
ax0.set_ylim([100,600])

scatter=ax1.scatter(x=over_50['age'],y=over_50['thalach'],c=over_50['target'],cmap='winter')
ax1.set(title='Max Heart Rate VS Age for heart disease',xlabel="Age in years",ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(),title='target')
ax1.axhline(over_50['thalach'].mean(),linestyle="--")
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

## add title to figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");
